# %%
import diagramService as ds
import pandas as pd
import accomodationService

dataFrame = accomodationService.loadTable()

allNights = dataFrame.foreign + dataFrame.domestic
foreignStat = dataFrame.foreign / allNights

diagramModel = pd.concat([dataFrame.county, allNights], axis=1, sort=False)

diagramModel.county = diagramModel.county.apply(lambda x: x.split("-")[0] if "-" in x else x)

diagramModel = diagramModel.sort_values(0, ascending=False)
# Out:
# 4     Budapest
# 19        Zala
# 17         Vas
# 8        Hajdú
# 9        Heves
# 13        Pest
# 7         Győr
# 18    Veszprém
# 3       Borsod
# 2        Békés
# 5     Csongrád
# 1      Baranya
# 14      Somogy
# 11     Komárom
# 6        Fejér
# 0         Bács
# 10        Jász
# 15    Szabolcs
# 16       Tolna
# 12      Nógrád
# Name: county, dtype: object

# %%
ds.plotAccomodation(diagramModel)
